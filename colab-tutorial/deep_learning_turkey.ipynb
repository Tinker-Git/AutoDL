# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls "/content/drive/My Drive/"
# Out:
#  111.gsheet
#  Backup
#  book-kindle
#  books
#  code-interview.ipynb
#  CV
#  Fall2015-2016
#  Fall2016-2017
#  Fall2017-2018
#  Fall2018-2019
#  Literature
#  Paper
#  paperwork
#  Photo
#  ScAi_Research
#  slideslive-recorder_20200721T182229.050Z_user.webm
#  Software
#  Spring2015-2016
#  Spring2016-2017
#  Spring2017-2018
#  Spring2019-2020
#  Study
# 'TA Template.gslides'
#  tripleshare
#  UCLA_CS_MS
#  UCLA_EE_PHD
# 'UCLA Unofficial Slides.gslides'
# 'Untitled spreadsheet.gsheet'
#  Winter2015-2016
#  Winter2016-2017
#  Winter2017-2018
#  Winter2019-2020
#  zzz_Archived

# %%
# !pip install -q keras

# %%
# !python3 "/content/drive/My Drive/tripleshare/AutoML/colab-tutorial/mnist_cnn.py"
# Out:
# 2020-09-18 22:59:47.376936: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# 2020-09-18 22:59:49.183525: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-09-18 22:59:49.219148: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-18 22:59:49.219743: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !wget https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv -P "/content/drive/My Drive/tripleshare/AutoML/colab-tutorial/"
# Out:
# --2020-09-18 23:04:30--  https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1170 (1.1K) [text/plain]
# Saving to: ‘/content/drive/My Drive/tripleshare/AutoML/colab-tutorial/Titanic.csv’
#
# Titanic.csv         100%[===================>]   1.14K  --.-KB/s    in 0s
#
# 2020-09-18 23:04:30 (56.5 MB/s) - ‘/content/drive/My Drive/tripleshare/AutoML/colab-tutorial/Titanic.csv’ saved [1170/1170]

# %%
import pandas as pd
titanic = pd.read_csv("/content/drive/My Drive/tripleshare/AutoML/colab-tutorial/Titanic.csv")
titanic.head(5)
# Out:
#    Unnamed: 0 Class     Sex    Age Survived  Freq
# 0           1   1st    Male  Child       No     0
# 1           2   2nd    Male  Child       No     0
# 2           3   3rd    Male  Child       No    35
# 3           4  Crew    Male  Child       No     0
# 4           5   1st  Female  Child       No     0
